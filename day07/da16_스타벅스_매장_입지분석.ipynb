# %% [markdown]
# ## 빅데이터 실습
#
# ### 스타벅스매장 입지 분석
#
# #### 데이터 수집
#
# ##### 데이터 전처리 마무리 하기

# %%
# 필요라이브러리 사용 등록
import pandas as pd
import folium
import json

# %%
# 서울시의 스타벅스 매장 정보 로드하기
dfStarbukcsSeoul = pd.read_excel('./data/starbucks_seoul_list.xlsx')

# %%
# 주소를 split으로 자른 다음에 배열의 1번 째 인덱스가 구이다.
# 기존 DataFrame에 구 추가하기
guName = []
for number in range(0,len(dfStarbukcsSeoul['주소'])):
    gu = dfStarbukcsSeoul['주소'][number].split(' ')[1]
    guName.append(gu)
df_guName = pd.DataFrame(guName)
dfStarbukcsSeoul['구'] = df_guName

# %%
dfStarbukcsSeoul.tail()
# Out:
#       매장명         위도          경도     매장타입  \
# 608  사가정역  37.579594  127.087966  general
# 609   상봉역  37.596890  127.086470  general
# 610    묵동  37.615368  127.076633  general
# 611   양원역  37.606654  127.106360  general
# 612   중화역  37.601709  127.078411  general
#
#                                         주소       전화번호    구
# 608                      서울특별시 중랑구 면목로 310  1522-3232  중랑구
# 609                서울특별시 중랑구 망우로 307 (상봉동)  1522-3232  중랑구
# 610  서울특별시 중랑구 동일로 952 (묵동, 로프트원 태릉입구역) 1층  1522-3232  중랑구
# 611              서울특별시 중랑구 양원역로10길 3 (망우동)  1522-3232  중랑구
# 612                   서울특별시 중랑구 봉화산로 35 1층  1522-3232  중랑구

# %%
dfStarbukcsSeoul.to_excel('./data/최종_서울_스타벅스매장리스트.xlsx',index=False)

# %%
# 스타벅스 분석 데이터 만들기
dfSeoulGuList = pd.read_excel('./data/수정_서울_시군구_위경도.xlsx')

# %%
dfSeoulGuList.tail()
# Out:
#    docity  do city   longitude   latitude
# 20  서울용산구  서울  용산구  126.967522  37.536094
# 21  서울은평구  서울  은평구  126.931242  37.599969
# 22  서울종로구  서울  종로구  126.981642  37.570378
# 23   서울중구  서울   중구  126.999642  37.561003
# 24  서울중랑구  서울  중랑구  127.094778  37.603806

# %%
dfSeoulGuLast = dfSeoulGuList[['do','city','latitude','longitude']]

# %%
# 각 칼럼의 영어이름은 한글 이름으로 변경
dfSeoulGuLast.columns = ['시','구','위도','경도']

# %%
dfSeoulGuLast.tail()
# Out:
#      시    구         위도          경도
# 20  서울  용산구  37.536094  126.967522
# 21  서울  은평구  37.599969  126.931242
# 22  서울  종로구  37.570378  126.981642
# 23  서울   중구  37.561003  126.999642
# 24  서울  중랑구  37.603806  127.094778

# %%
dfSeoulGuLast.to_excel('./data/최종_서울_구리스트.xlsx',index=False)

# %%
# 서울시 스타벅스 매장리스트에서 구별 데이터 합산(pivot_table)
seoulStarbukcsGuCount = dfStarbukcsSeoul.pivot_table(values='매장명',index='구',aggfunc='count').rename(columns={'매장명':'매장수'})

# %%
seoulStarbukcsGuCount.tail()
# Out:
#      매장수
# 구
# 용산구   24
# 은평구   14
# 종로구   40
# 중구    54
# 중랑구    8

# %%
# 서울구 리스트에 스타벅스구별 매장수를 병합 last를 앞이 붙이면 진짜 최종 데이터!!!!
lastSbSeoulCount = pd.merge(left=dfSeoulGuLast,right=seoulStarbukcsGuCount,how='left',on='구')

# %%
lastSbSeoulCount
# Out:
#      시     구         위도          경도  매장수
# 0   서울   강남구  37.514575  127.049556   91
# 1   서울   강동구  37.527367  127.125864   17
# 2   서울   강북구  37.636956  127.027719    6
# 3   서울   강서구  37.548156  126.851675   27
# 4   서울   관악구  37.475386  126.953844   12
# 5   서울   광진구  37.535739  127.084533   18
# 6   서울   구로구  37.492650  126.889597   14
# 7   서울   금천구  37.449108  126.904197   13
# 8   서울   노원구  37.651461  127.058389   14
# 9   서울   도봉구  37.665833  127.049522    7
# 10  서울  동대문구  37.571625  127.042142   13
# 11  서울   동작구  37.509656  126.941575   11
# 12  서울   마포구  37.560706  126.910531   36
# 13  서울  서대문구  37.576367  126.938897   22
# 14  서울   서초구  37.480786  127.034811   48
# 15  서울   성동구  37.560611  127.039000   14
# 16  서울   성북구  37.586383  127.020333   15
# 17  서울   송파구  37.511756  127.107931   36
# 18  서울   양천구  37.514231  126.868708   17
# 19  서울  영등포구  37.523611  126.898342   42
# 20  서울   용산구  37.536094  126.967522   24
# 21  서울   은평구  37.599969  126.931242   14
# 22  서울   종로구  37.570378  126.981642   40
# 23  서울    중구  37.561003  126.999642   54
# 24  서울   중랑구  37.603806  127.094778    8

# %%
#서울시 구별 인구통계 로드하기
dfSeoulGuPop = pd.read_excel('./data/수정_서울_구별인구.xlsx',usecols=['구','성별소계'])
dfSeoulGuPop.tail()
# Out:
#       구    성별소계
# 21  관악구  497883
# 22  서초구  412078
# 23  강남구  550282
# 24  송파구  660025
# 25  강동구  463318

# %%
lastSbSeoulCount = pd.merge(left=lastSbSeoulCount,right=dfSeoulGuPop,how='left',left_on='구',right_on='성별소계').drop(['구_x','소계_x','구_y','소계_y'],axis=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 lastSbSeoulCount = pd.merge(left=lastSbSeoulCount,right=dfSeoulGuPop,how='left',left_on='구',right_on='성별소계').drop(['구_x','소계_x','구_y','소계_y'],axis=1)
#
# File c:\DEV\Python312\Lib\site-packages\pandas\core\reshape\merge.py:170, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     155     return _cross_merge(
#     156         left_df,
#     157         right_df,
#    (...)
#     167         copy=copy,
#     168     )
#     169 else:
# --> 170     op = _MergeOperation(
#     171         left_df,
#     172         right_df,
#     173         how=how,
#     174         on=on,
#     175         left_on=left_on,
#     176         right_on=right_on,
#     177         left_index=left_index,
#     178         right_index=right_index,
#     179         sort=sort,
#     180         suffixes=suffixes,
#     181         indicator=indicator,
#     182         validate=validate,
#     183     )
#     184     return op.get_result(copy=copy)
#
# File c:\DEV\Python312\Lib\site-packages\pandas\core\reshape\merge.py:807, in _MergeOperation.__init__(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
#     803 self._validate_tolerance(self.left_join_keys)
#     805 # validate the merge keys dtypes. We may need to coerce
#     806 # to avoid incompatible dtypes
# --> 807 self._maybe_coerce_merge_keys()
#     809 # If argument passed to validate,
#     810 # check if columns specified as unique
#     811 # are in fact unique.
#     812 if validate is not None:
#
# File c:\DEV\Python312\Lib\site-packages\pandas\core\reshape\merge.py:1508, in _MergeOperation._maybe_coerce_merge_keys(self)
#    1502     # unless we are merging non-string-like with string-like
#    1503     elif (
#    1504         inferred_left in string_types and inferred_right not in string_types
#    1505     ) or (
#    1506         inferred_right in string_types and inferred_left not in string_types
#    1507     ):
# -> 1508         raise ValueError(msg)
#    1510 # datetimelikes must match exactly
#    1511 elif needs_i8_conversion(lk.dtype) and not needs_i8_conversion(rk.dtype):
#
# ValueError: You are trying to merge on object and int64 columns for key '구'. If you wish to proceed you should use pd.concat

# %%
lastSbSeoulCount.columns = ['시','구','위도','경도','스차벅스매장수','구별','주민등록인구']
lastSbSeoulCount.drop('구별',axis=1,inplace=True)

# %%
lastSbSeoulCount.tail()
# Out:
#      시    구         위도          경도  스차벅스매장수  주민등록인구
# 20  서울  용산구  37.536094  126.967522       24  227106
# 21  서울  은평구  37.599969  126.931242       14  470869
# 22  서울  종로구  37.570378  126.981642       40  150453
# 23  서울   중구  37.561003  126.999642       54  131793
# 24  서울  중랑구  37.603806  127.094778        8  387470

# %%
dfSeoulGuBiz = pd.read_excel('./data/수정_서울_구별사업체.xlsx',usecols=['구','소계','종사자수 소계'])
dfSeoulGuBiz.tail()
# Out:
#       구      소계  종사자수 소계
# 21  관악구   37915   128417
# 22  서초구   71958   487976
# 23  강남구  110007   801419
# 24  송파구   74531   400781
# 25  강동구   41660   157465

# %%
## 사업체 정보에서 컬럼이름부터 변경
dfSeoulGuBiz.columns = ['구','사업체수','종사자수']
dfSeoulGuBiz.tail()
# Out:
#       구    사업체수    종사자수
# 21  관악구   37915  128417
# 22  서초구   71958  487976
# 23  강남구  110007  801419
# 24  송파구   74531  400781
# 25  강동구   41660  157465

# %%
# 사업체 정보를 스타벅스 최종 데이터에 병합
lastSbSeoulCount = pd.merge(left=lastSbSeoulCount,right=dfSeoulGuBiz,how='left',on='구')

# %%
lastSbSeoulCount.to_excel('./data/최종_서울_스타벅스매장_데이터.xlsx',index=False)

# %% [markdown]
# ##### 스타벅스 분석 시각화

# %%
dfStarbucksSeoul = pd.read_excel('./data/최종_서울_스타벅스매장리스트.xlsx')
dfStarbucksSeoul.tail()
# Out:
#       매장명         위도          경도    매장 타입  \
# 608  사가정역  37.579594  127.087966  general
# 609   상봉역  37.596890  127.086470  general
# 610    묵동  37.615368  127.076633  general
# 611   양원역  37.606654  127.106360  general
# 612   중화역  37.601709  127.078411  general
#
#                                         주소       전화번호    구
# 608                      서울특별시 중랑구 면목로 310  1522-3232  중랑구
# 609                서울특별시 중랑구 망우로 307 (상봉동)  1522-3232  중랑구
# 610  서울특별시 중랑구 동일로 952 (묵동, 로프트원 태릉입구역) 1층  1522-3232  중랑구
# 611              서울특별시 중랑구 양원역로10길 3 (망우동)  1522-3232  중랑구
# 612                   서울특별시 중랑구 봉화산로 35 1층  1522-3232  중랑구

# %%
dfStarbukcsSeoulCount = pd.read_excel('./data/최종_서울_스타벅스매장_데이터.xlsx')
dfStarbukcsSeoulCount.tail()
# Out:
#      시    구         위도          경도  스차벅스매장수  주민등록인구   사업체수    종사자수
# 20  서울  용산구  37.536094  126.967522       24  227106  29680  152605
# 21  서울  은평구  37.599969  126.931242       14  470869  36509  109031
# 22  서울  종로구  37.570378  126.981642       40  150453  48361  275063
# 23  서울   중구  37.561003  126.999642       54  131793  70308  386564
# 24  서울  중랑구  37.603806  127.094778        8  387470  39310  113144

# %%
#서울시 지도 생성
seoulLoc = (37.573050,126.979169)
seoulMap = folium.Map(location=(37.573050,126.979169),zoom_start=11)

# 각 매장별 위치를 지도에 마커로 표시
for idx in range(0,len(dfStarbucksSeoul)):
    lat = dfStarbucksSeoul.loc[idx,'위도']
    lng = dfStarbucksSeoul.loc[idx,'경도']
    type = dfStarbucksSeoul.loc[idx,'매장 타입']
    if type == 'general':
        folium.CircleMarker(location=(lat,lng),popup=f'{dfStarbucksSeoul.loc[idx,'매장명']}점',fill=True,fill_color='green',
                        fill_opacity=2,color='yellow',radius=4,weight=1).add_to(seoulMap)
    elif type == 'reserve':
        folium.CircleMarker(location=(lat,lng),popup=f'{dfStarbucksSeoul.loc[idx,'매장명']}점',fill=True,fill_color='black',
                        fill_opacity=2,color='yellow',radius=4,weight=1).add_to(seoulMap)
    elif type == 'generalDT':
        folium.CircleMarker(location=(lat,lng),popup=f'{dfStarbucksSeoul.loc[idx,'매장명']}점',fill=True,fill_color='red',
                        fill_opacity=2,color='yellow',radius=4,weight=1).add_to(seoulMap)
    elif type == 'generalWT':
        folium.CircleMarker(location=(lat,lng),popup=f'{dfStarbucksSeoul.loc[idx,'매장명']}점',fill=True,fill_color='violet',
                        fill_opacity=2,color='yellow',radius=4,weight=1).add_to(seoulMap)

seoulMap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a97f46f5fa6e6f5480ade5efe94ec0b5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a97f46f5fa6e6f5480ade5efe94ec0b5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a97f46f5fa6e6f5480ade5efe94ec0b5 = L.map(
#                 &quot;map_a97f46f5fa6e6f5480ade5efe94ec0b5&quot;,
#                 {
#                     center: [37.57305, 126.979169],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_28538319aec739e2fbce405fca8f3010 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_28538319aec739e2fbce405fca8f3010.addTo(map_a97f46f5fa6e6f5480ade5efe94ec0b5);
#
#
#             var circle_marker_d401f75b3ed3273db1b52461e2fe089d = L.circleMarker(
#                 [37.501087, 127.043069],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_a97f46f5fa6e6f5480ade5efe94ec0b5);
#
#
#         var popup_0a3b6945ef16fa690a3394252242a394 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_53b3ce2f9227ea126505bd0945164e83 = $(`&lt;div id=&quot;html_53b3ce2f9227ea126505bd0945164e83&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;역삼아레나빌딩점&lt;/div&gt;`)[0];
#                 popup_0a3b6945ef16fa690a3394252242a394.setContent(html_53b3ce2f9227ea126505bd0945164e83);
#
#
#
#         circle_marker_d401f75b3ed3273db1b52461e2fe089d.bindPopup(popup_0a3b6945ef16fa690a3394252242a394)
#         ;
#
#
#
#
#             var circle_marker_38aa444dd56822291e9c37e52adb9cf4 = L.circleMarker(
#                 [37.510178, 127.022223],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_a97f46f5fa6e6f5480ade5efe94ec0b5);
#
#
#         var popup_7f687c1bbd7211a5281880ae811a43e8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_eb3428c5a8ffaeff453940967e0a23eb = $(`&lt;div id=&quot;html_eb3428c5a8ffaeff453940967e0a23eb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;논현역사거리점&lt;/div&gt;`)[0];
#                 popup_7f687c1bbd7211a5281880ae811a43e8.setContent(html_eb3428c5a8ffaeff453940967e0a23eb);
#
#
#
#         circle_marker_38aa444dd56822291e9c37e52adb9cf4.bindPopup(popup_7f687c1bbd7211a5281880ae811a43e8)
#         ;
#
#
#
#
#             var circle_marker_5fdd2797b65cf6d9b5a2b1d9515d2eef = L.circleMarker(
#                 [37.5139309, 127.0206057],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_a97f46f5fa6e6f5480ade5efe94ec0b5);
#
#
#         var popup_51ac8a62bf77942d68ee45cf7aaef952 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b076914b11c5a20e0c5fa57712595cd1 = $(`&lt;div id=&quot;html_b076914b11c5a20e0c5fa57712595cd1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;신사역성일빌딩점&lt;/div&gt;`)[0];
#                 popup_51ac8a62bf77942d68ee45cf7aaef952.setContent(html_b076914b11c5a20e0c5fa57712595cd1);
#
#
#
#         circle_marker_5fdd2797b65cf6d9b5a2b1d9515d2eef.bindPopup(popup_51ac8a62bf77942d68ee45cf7aaef952)
#         ;
#
#
#
#
#             var circle_marker_055948a6e8a6934a75e004bf44f42eda = L.circleMarker(
#                 [37.499517, 127.031495],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 2, &quo

# %%
#매장 타입 개수
dfStarbucksSeoul['매장 타입'].value_counts()
# Out:
# 매장 타입
# general      552
# reserve       36
# generalDT     23
# generalWT      2
# Name: count, dtype: int64

# %%
seoulLoc = (37.573050,126.979169)
sbMap = folium.Map(location=(37.573050,126.979169),zoom_start=11)

# 각 매장별 위치를 지도에 마커로 표시
for idx in range(0,len(dfStarbucksSeoul)):
    lat = dfStarbucksSeoul.loc[idx,'위도']
    lng = dfStarbucksSeoul.loc[idx,'경도']
    store_type = dfStarbucksSeoul.loc[idx,'매장 타입']
    folium.CircleMarker(location=(lat,lng),popup=f'{dfStarbucksSeoul.loc[idx,'매장명']}점',fill=True,fill_color='green',
                fill_opacity=2,color='yellow',radius=4,weight=1).add_to(sbMap)
